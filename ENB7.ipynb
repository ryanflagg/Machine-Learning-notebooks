# %% [markdown]
# <h1>ENB7</h1><br>
# <h2>same FF networks as ENB5 & 6 but with 14 epochs</h2><br>
# Some more experimentation with simple feed forward networks.  These experiments will be simple and will follow some of the guidance I've found re; starting points with layers and neurons.  I will be keeping the number hidden layers limited to no greater than 2 for this round of experiments and all of the layers will have the same number of nuerons. The number of nuerons will be determined as a % of the input layer and will be 150%, 125%, 100%, 75%, 50% & 25%.

# %%
summary =[]
test_no = 1

# %%
import numpy as np
import tensorflow as tf
import os
import csv
import matplotlib.pyplot as plt
from keras import models
from keras import layers
# Out:
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Ryan\anaconda3\envs\tensorflow_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# <h2>Pre-processing</h2>

# %%
import pre_process as pp

# %%
import pickle

# %%
data, labels = pp.pre_process()
# Out:
# concatenating files
# AReMv1\bending1\dataset1.csv
# AReMv1\bending1\dataset2.csv
# AReMv1\bending1\dataset3.csv
# AReMv1\bending1\dataset4.csv
# AReMv1\bending1\dataset5.csv
# AReMv1\bending1\dataset6.csv
# AReMv1\bending1\dataset7.csv
# AReMv1\bending2\dataset1.csv
# AReMv1\bending2\dataset2.csv
# AReMv1\bending2\dataset3.csv
# AReMv1\bending2\dataset5.csv
# AReMv1\bending2\dataset6.csv
# AReMv1\cycling\dataset1.csv
# AReMv1\cycling\dataset10.csv
# AReMv1\cycling\dataset11.csv
# AReMv1\cycling\dataset12.csv
# AReMv1\cycling\dataset13.csv
# AReMv1\cycling\dataset14.csv
# AReMv1\cycling\dataset15.csv
# AReMv1\cycling\dataset2.csv
# AReMv1\cycling\dataset3.csv
# AReMv1\cycling\dataset4.csv
# AReMv1\cycling\dataset5.csv
# AReMv1\cycling\dataset6.csv
# AReMv1\cycling\dataset7.csv
# AReMv1\cycling\dataset8.csv
# AReMv1\cycling\dataset9.csv
# AReMv1\lying\dataset1.csv
# AReMv1\lying\dataset10.csv
# AReMv1\lying\dataset11.csv
# AReMv1\lying\dataset12.csv
# AReMv1\lying\dataset13.csv
# AReMv1\lying\dataset14.csv
# AReMv1\lying\dataset15.csv
# AReMv1\lying\dataset2.csv
# AReMv1\lying\dataset3.csv
# AReMv1\lying\dataset4.csv
# AReMv1\lying\dataset5.csv
# AReMv1\lying\dataset6.csv
# AReMv1\lying\dataset7.csv
# AReMv1\lying\dataset8.csv
# AReMv1\lying\dataset9.csv
# AReMv1\sitting\dataset1.csv
# AReMv1\sitting\dataset10.csv
# AReMv1\sitting\dataset11.csv
# AReMv1\sitting\dataset12.csv
# AReMv1\sitting\dataset13.csv
# AReMv1\sitting\dataset14.csv
# AReMv1\sitting\dataset15.csv
# AReMv1\sitting\dataset2.csv
# AReMv1\sitting\dataset3.csv
# AReMv1\sitting\dataset4.csv
# AReMv1\sitting\dataset5.csv
# AReMv1\sitting\dataset6.csv
# AReMv1\sitting\dataset7.csv
# AReMv1\sitting\dataset8.csv
# AReMv1\sitting\dataset9.csv
# AReMv1\standing\dataset1.csv
# AReMv1\standing\dataset10.csv
# AReMv1\standing\dataset11.csv
# AReMv1\standing\dataset12.csv
# AReMv1\standing\dataset13.csv
# AReMv1\standing\dataset14.csv
# AReMv1\standing\dataset15.csv
# AReMv1\standing\dataset2.csv
# AReMv1\standing\dataset3.csv
# AReMv1\standing\dataset4.csv
# AReMv1\standing\dataset5.csv
# AReMv1\standing\dataset6.csv
# AReMv1\standing\dataset7.csv
# AReMv1\standing\dataset8.csv
# AReMv1\standing\dataset9.csv
# AReMv1\walking\dataset1.csv
# AReMv1\walking\dataset10.csv
# AReMv1\walking\dataset11.csv
# AReMv1\walking\dataset12.csv
# AReMv1\walking\dataset13.csv
# AReMv1\walking\dataset14.csv
# AReMv1\walking\dataset15.csv
# AReMv1\walking\dataset2.csv
# AReMv1\walking\dataset3.csv
# AReMv1\walking\dataset4.csv
# AReMv1\walking\dataset5.csv
# AReMv1\walking\dataset6.csv
# AReMv1\walking\dataset7.csv
# AReMv1\walking\dataset8.csv
# AReMv1\walking\dataset9.csv
# Tokenising labels
# bending1 = 0
# bending1 = 0
# bending1 = 0
# bending1 = 0
# bending1 = 0
# bending1 = 0
# bending1 = 0
# bending2 = 1
# bending2 = 1
# bending2 = 1
# bending2 = 1
# bending2 = 1
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# cycling = 2
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# lying = 3
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# sitting = 4
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# standing = 5
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# walking = 6
# data shape:
# (87, 480, 6)
# labels shape:
# (87,)

# %%
train_data, train_labels, val_data, val_labels, test_data, test_labels = pp.cluster_shuffle(data, labels)
# Out:
# SHUFFLING ARRAYS
# act0 shape:  (7, 480, 6)
# act1 shape:  (5, 480, 6)
# act2 shape:  (15, 480, 6)
# act3 shape:  (15, 480, 6)
# act4 shape:  (15, 480, 6)
# act5 shape:  (15, 480, 6)
# act6 shape:  (15, 480, 6)
# SLICING ARRAYS
# (4, 480, 6)
# (2, 480, 6)
# (1, 480, 6)

# %% [markdown]
# <h2>Exp:7a</h2><br>
# 1 layer, 720 neurons

# %%
net = models.Sequential()
net.add(layers.Dense(480, input_shape = (480,6)))
net.add(layers.Dense (720, activation = 'relu'))
net.add(layers.Flatten())
net.add(layers.Dense(7, activation = 'sigmoid'))
net.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_73 (Dense)             (None, 480, 480)          3360
# _________________________________________________________________
# dense_74 (Dense)             (None, 480, 720)          346320
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 345600)            0
# _________________________________________________________________
# dense_75 (Dense)             (None, 7)                 2419207
# =================================================================
# Total params: 2,768,887
# Trainable params: 2,768,887
# Non-trainable params: 0
# _________________________________________________________________

# %%
net.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
hist = net.fit(train_data, train_labels, epochs = 14, validation_data = (val_data, val_labels))
# Out:
# Train on 52 samples, validate on 18 samples
# Epoch 1/14
# 52/52 [==============================] - 1s 19ms/step - loss: 2.6625 - accuracy: 0.2115 - val_loss: 1.9022 - val_accuracy: 0.2222
# Epoch 2/14
# 52/52 [==============================] - 0s 9ms/step - loss: 1.8749 - accuracy: 0.2885 - val_loss: 1.7676 - val_accuracy: 0.1667
# Epoch 3/14
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7412 - accuracy: 0.1731 - val_loss: 1.6235 - val_accuracy: 0.2222
# Epoch 4/14
# 52/52 [==============================] - 0s 9ms/step - loss: 1.5729 - accuracy: 0.3269 - val_loss: 1.3742 - val_accuracy: 0.3333
# Epoch 5/14
# 52/52 [==============================] - 0s 9ms/step - loss: 1.2929 - accuracy: 0.4038 - val_loss: 1.1087 - val_accuracy: 0.4444
# Epoch 6/14
# 52/52 [==============================] - 0s 9ms/step - loss: 1.1288 - accuracy: 0.6346 - val_loss: 1.1703 - val_accuracy: 0.3333
# Epoch 7/14
# 52/52 [==============================] - 0s 9ms/step - loss: 1.0839 - accuracy: 0.3269 - val_loss: 1.0316 - val_accuracy: 0.3889
# Epoch 8/14
# 52/52 [==============================] - 0s 9ms/step - loss: 0.8282 - accuracy: 0.5962 - val_loss: 1.0630 - val_accuracy: 0.6111
# Epoch 9/14
# 52/52 [==============================] - 0s 9ms/step - loss: 0.9253 - accuracy: 0.6923 - val_loss: 0.8828 - val_accuracy: 0.6111
# Epoch 10/14
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5975 - accuracy: 0.7500 - val_loss: 1.0883 - val_accuracy: 0.5000
# Epoch 11/14
# 52/52 [==============================] - 0s 9ms/step - loss: 0.7908 - accuracy: 0.5577 - val_loss: 0.9421 - val_accuracy: 0.5000
# Epoch 12/14
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5952 - accuracy: 0.5962 - val_loss: 1.0012 - val_accuracy: 0.5556
# Epoch 13/14
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5827 - accuracy: 0.6538 - val_loss: 0.9863 - val_accuracy: 0.6111
# Epoch 14/14
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5004 - accuracy: 0.8846 - val_loss: 0.8464 - val_accuracy: 0.6111

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy','Validation'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['loss','validation loss'], loc='upper right')
plt.show()

# %%
f = net.evaluate(test_data, test_labels)
f.insert(0,'720')
f.insert(1,test_no)
test_no = test_no + 1
summary.append(f)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %% [markdown]
# <h2>Exp:7b</h2><br>
# 1layer 600 nuerons

# %%
net = models.Sequential()
net.add(layers.Dense(480, input_shape = (480,6)))
net.add(layers.Dense (600, activation = 'relu'))
net.add(layers.Flatten())
net.add(layers.Dense(7, activation = 'sigmoid'))
net.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_76 (Dense)             (None, 480, 480)          3360
# _________________________________________________________________
# dense_77 (Dense)             (None, 480, 600)          288600
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 288000)            0
# _________________________________________________________________
# dense_78 (Dense)             (None, 7)                 2016007
# =================================================================
# Total params: 2,307,967
# Trainable params: 2,307,967
# Non-trainable params: 0
# _________________________________________________________________

# %%
net.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
hist = net.fit(train_data, train_labels, epochs = 14, validation_data = (val_data, val_labels))
# Out:
# Train on 52 samples, validate on 18 samples
# Epoch 1/14
# 52/52 [==============================] - 1s 18ms/step - loss: 2.2156 - accuracy: 0.2308 - val_loss: 1.8308 - val_accuracy: 0.1667
# Epoch 2/14
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7903 - accuracy: 0.1731 - val_loss: 1.6928 - val_accuracy: 0.1667
# Epoch 3/14
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6508 - accuracy: 0.1731 - val_loss: 1.5180 - val_accuracy: 0.1667
# Epoch 4/14
# 52/52 [==============================] - 0s 8ms/step - loss: 1.4369 - accuracy: 0.1731 - val_loss: 1.2676 - val_accuracy: 0.4444
# Epoch 5/14
# 52/52 [==============================] - 0s 8ms/step - loss: 1.1896 - accuracy: 0.4615 - val_loss: 1.0089 - val_accuracy: 0.6111
# Epoch 6/14
# 52/52 [==============================] - 0s 8ms/step - loss: 0.9692 - accuracy: 0.6731 - val_loss: 0.9339 - val_accuracy: 0.4444
# Epoch 7/14
# 52/52 [==============================] - 0s 8ms/step - loss: 0.8803 - accuracy: 0.5769 - val_loss: 0.9445 - val_accuracy: 0.6111
# Epoch 8/14
# 52/52 [==============================] - 0s 8ms/step - loss: 0.8236 - accuracy: 0.6346 - val_loss: 0.9339 - val_accuracy: 0.5556
# Epoch 9/14
# 52/52 [==============================] - 0s 8ms/step - loss: 0.5837 - accuracy: 0.6923 - val_loss: 1.1575 - val_accuracy: 0.5556
# Epoch 10/14
# 52/52 [==============================] - 0s 8ms/step - loss: 0.9754 - accuracy: 0.6154 - val_loss: 0.7809 - val_accuracy: 0.5000
# Epoch 11/14
# 52/52 [==============================] - 0s 8ms/step - loss: 0.5185 - accuracy: 0.7885 - val_loss: 1.0918 - val_accuracy: 0.5000
# Epoch 12/14
# 52/52 [==============================] - 0s 8ms/step - loss: 0.7541 - accuracy: 0.7308 - val_loss: 0.8547 - val_accuracy: 0.6111
# Epoch 13/14
# 52/52 [==============================] - 0s 8ms/step - loss: 0.3783 - accuracy: 0.8269 - val_loss: 0.9229 - val_accuracy: 0.5556
# Epoch 14/14
# 52/52 [==============================] - 0s 8ms/step - loss: 0.5716 - accuracy: 0.8462 - val_loss: 0.8885 - val_accuracy: 0.5000

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy','Validation'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['loss','validation loss'], loc='upper right')
plt.show()

# %%
f = net.evaluate(test_data, test_labels)
f.insert(0,'600')
f.insert(1,test_no)
test_no = test_no + 1
summary.append(f)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %% [markdown]
# <h2>Exp:7c</h2><br>
# 1 layer 480 nuerons

# %%
net = models.Sequential()
net.add(layers.Dense(480, input_shape = (480,6)))
net.add(layers.Dense (480, activation = 'relu'))
net.add(layers.Flatten())
net.add(layers.Dense(7, activation = 'sigmoid'))
net.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_79 (Dense)             (None, 480, 480)          3360
# _________________________________________________________________
# dense_80 (Dense)             (None, 480, 480)          230880
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 230400)            0
# _________________________________________________________________
# dense_81 (Dense)             (None, 7)                 1612807
# =================================================================
# Total params: 1,847,047
# Trainable params: 1,847,047
# Non-trainable params: 0
# _________________________________________________________________

# %%
net.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
hist = net.fit(train_data, train_labels, epochs = 14, validation_data = (val_data, val_labels))
# Out:
# Train on 52 samples, validate on 18 samples
# Epoch 1/14
# 52/52 [==============================] - 1s 17ms/step - loss: 2.1224 - accuracy: 0.1538 - val_loss: 1.9024 - val_accuracy: 0.1667
# Epoch 2/14
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8285 - accuracy: 0.1731 - val_loss: 1.6952 - val_accuracy: 0.2778
# Epoch 3/14
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6339 - accuracy: 0.4231 - val_loss: 1.5359 - val_accuracy: 0.3333
# Epoch 4/14
# 52/52 [==============================] - 0s 6ms/step - loss: 1.4511 - accuracy: 0.3846 - val_loss: 1.2275 - val_accuracy: 0.4444
# Epoch 5/14
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1224 - accuracy: 0.5962 - val_loss: 1.0991 - val_accuracy: 0.5000
# Epoch 6/14
# 52/52 [==============================] - 0s 6ms/step - loss: 0.9778 - accuracy: 0.5577 - val_loss: 0.8989 - val_accuracy: 0.6111
# Epoch 7/14
# 52/52 [==============================] - 0s 6ms/step - loss: 0.7231 - accuracy: 0.7115 - val_loss: 0.8113 - val_accuracy: 0.5000
# Epoch 8/14
# 52/52 [==============================] - 0s 6ms/step - loss: 0.6708 - accuracy: 0.6923 - val_loss: 0.7519 - val_accuracy: 0.6667
# Epoch 9/14
# 52/52 [==============================] - 0s 6ms/step - loss: 0.4766 - accuracy: 0.8654 - val_loss: 0.9125 - val_accuracy: 0.5556
# Epoch 10/14
# 52/52 [==============================] - 0s 6ms/step - loss: 0.4780 - accuracy: 0.8269 - val_loss: 0.7830 - val_accuracy: 0.6111
# Epoch 11/14
# 52/52 [==============================] - 0s 6ms/step - loss: 0.4129 - accuracy: 0.7885 - val_loss: 0.7698 - val_accuracy: 0.6667
# Epoch 12/14
# 52/52 [==============================] - 0s 6ms/step - loss: 0.3342 - accuracy: 0.8462 - val_loss: 0.7371 - val_accuracy: 0.6667
# Epoch 13/14
# 52/52 [==============================] - 0s 6ms/step - loss: 0.2612 - accuracy: 0.9038 - val_loss: 0.9293 - val_accuracy: 0.6111
# Epoch 14/14
# 52/52 [==============================] - 0s 6ms/step - loss: 0.2481 - accuracy: 0.8846 - val_loss: 0.9196 - val_accuracy: 0.5000

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy','Validation'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['loss','validation loss'], loc='upper right')
plt.show()

# %%
f = net.evaluate(test_data, test_labels)
f.insert(0,'480')
f.insert(1,test_no)
test_no = test_no + 1
summary.append(f)
# Out:
# 17/17 [==============================] - 0s 2ms/step

# %% [markdown]
# <h2>Exp:7d</h2>
# <br>
# 1 layer 360 neurons

# %%
net = models.Sequential()
net.add(layers.Dense(480, input_shape = (480,6)))
net.add(layers.Dense (360, activation = 'relu'))
net.add(layers.Flatten())
net.add(layers.Dense(7, activation = 'sigmoid'))
net.summary()
# Out:
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_82 (Dense)             (None, 480, 480)          3360
# _________________________________________________________________
# dense_83 (Dense)             (None, 480, 360)          173160
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 172800)            0
# _________________________________________________________________
# dense_84 (Dense)             (None, 7)                 1209607
# =================================================================
# Total params: 1,386,127
# Trainable params: 1,386,127
# Non-trainable params: 0
# _________________________________________________________________

# %%
net.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
hist = net.fit(train_data, train_labels, epochs = 14, validation_data = (val_data, val_labels))
# Out:
# Train on 52 samples, validate on 18 samples
# Epoch 1/14
# 52/52 [==============================] - 1s 16ms/step - loss: 2.1114 - accuracy: 0.1346 - val_loss: 1.8187 - val_accuracy: 0.1667
# Epoch 2/14
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7651 - accuracy: 0.1731 - val_loss: 1.6681 - val_accuracy: 0.2778
# Epoch 3/14
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5903 - accuracy: 0.2692 - val_loss: 1.3271 - val_accuracy: 0.4444
# Epoch 4/14
# 52/52 [==============================] - 0s 5ms/step - loss: 1.2156 - accuracy: 0.5769 - val_loss: 1.1912 - val_accuracy: 0.4444
# Epoch 5/14
# 52/52 [==============================] - 0s 5ms/step - loss: 1.2132 - accuracy: 0.5192 - val_loss: 1.0830 - val_accuracy: 0.3333
# Epoch 6/14
# 52/52 [==============================] - 0s 5ms/step - loss: 0.8626 - accuracy: 0.5385 - val_loss: 1.1675 - val_accuracy: 0.6111
# Epoch 7/14
# 52/52 [==============================] - 0s 5ms/step - loss: 0.9739 - accuracy: 0.6923 - val_loss: 0.9719 - val_accuracy: 0.6111
# Epoch 8/14
# 52/52 [==============================] - 0s 5ms/step - loss: 0.8246 - accuracy: 0.7692 - val_loss: 0.8945 - val_accuracy: 0.5000
# Epoch 9/14
# 52/52 [==============================] - 0s 5ms/step - loss: 0.6229 - accuracy: 0.7500 - val_loss: 1.1883 - val_accuracy: 0.3333
# Epoch 10/14
# 52/52 [==============================] - 0s 5ms/step - loss: 0.6725 - accuracy: 0.6538 - val_loss: 0.8912 - val_accuracy: 0.3889
# Epoch 11/14
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5113 - accuracy: 0.8269 - val_loss: 0.8803 - val_accuracy: 0.6111
# Epoch 12/14
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4410 - accuracy: 0.8654 - val_loss: 0.7299 - val_accuracy: 0.7222
# Epoch 13/14
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2976 - accuracy: 0.9423 - val_loss: 0.8773 - val_accuracy: 0.6111
# Epoch 14/14
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3409 - accuracy: 0.8654 - val_loss: 0.7265 - val_accuracy: 0.6111

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy','Validation'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['loss','validation loss'], loc='upper right')
plt.show()

# %%
f = net.evaluate(test_data, test_labels)
f.insert(0,'360')
f.insert(1,test_no)
test_no = test_no + 1
summary.append(f)
# Out:
# 17/17 [==============================] - 0s 2ms/step

# %% [markdown]
# <h2>Exp:7e</h2><br>
# 1 layer 240 neurons

# %%
net = models.Sequential()
net.add(layers.Dense(480, input_shape = (480,6)))
net.add(layers.Dense (240, activation = 'relu'))
net.add(layers.Flatten())
net.add(layers.Dense(7, activation = 'sigmoid'))
net.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_85 (Dense)             (None, 480, 480)          3360
# _________________________________________________________________
# dense_86 (Dense)             (None, 480, 240)          115440
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 115200)            0
# _________________________________________________________________
# dense_87 (Dense)             (None, 7)                 806407
# =================================================================
# Total params: 925,207
# Trainable params: 925,207
# Non-trainable params: 0
# _________________________________________________________________

# %%
net.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
hist = net.fit(train_data, train_labels, epochs = 14, validation_data = (val_data, val_labels))
# Out:
# Train on 52 samples, validate on 18 samples
# Epoch 1/14
# 52/52 [==============================] - 1s 15ms/step - loss: 2.1071 - accuracy: 0.1154 - val_loss: 1.8321 - val_accuracy: 0.1667
# Epoch 2/14
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8237 - accuracy: 0.2115 - val_loss: 1.7184 - val_accuracy: 0.2222
# Epoch 3/14
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6814 - accuracy: 0.3077 - val_loss: 1.5516 - val_accuracy: 0.3333
# Epoch 4/14
# 52/52 [==============================] - 0s 3ms/step - loss: 1.4953 - accuracy: 0.4231 - val_loss: 1.3117 - val_accuracy: 0.3889
# Epoch 5/14
# 52/52 [==============================] - 0s 4ms/step - loss: 1.2237 - accuracy: 0.3462 - val_loss: 1.0738 - val_accuracy: 0.5556
# Epoch 6/14
# 52/52 [==============================] - 0s 4ms/step - loss: 0.9429 - accuracy: 0.7115 - val_loss: 1.0043 - val_accuracy: 0.6111
# Epoch 7/14
# 52/52 [==============================] - 0s 4ms/step - loss: 0.8601 - accuracy: 0.5962 - val_loss: 0.9798 - val_accuracy: 0.6111
# Epoch 8/14
# 52/52 [==============================] - 0s 4ms/step - loss: 0.8931 - accuracy: 0.6538 - val_loss: 0.7882 - val_accuracy: 0.5000
# Epoch 9/14
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6454 - accuracy: 0.7692 - val_loss: 0.8749 - val_accuracy: 0.6111
# Epoch 10/14
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6037 - accuracy: 0.7308 - val_loss: 0.7881 - val_accuracy: 0.6667
# Epoch 11/14
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5563 - accuracy: 0.7885 - val_loss: 0.6277 - val_accuracy: 0.8333
# Epoch 12/14
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3865 - accuracy: 0.9231 - val_loss: 0.7056 - val_accuracy: 0.7778
# Epoch 13/14
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3515 - accuracy: 0.9038 - val_loss: 0.6128 - val_accuracy: 0.7222
# Epoch 14/14
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2785 - accuracy: 0.9423 - val_loss: 0.6195 - val_accuracy: 0.7222

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy','Validation'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['loss','validation loss'], loc='upper right')
plt.show()

# %%
f = net.evaluate(test_data, test_labels)
f.insert(0,'240')
f.insert(1,test_no)
test_no = test_no + 1
summary.append(f)
# Out:
# 17/17 [==============================] - 0s 1ms/step

# %% [markdown]
# <h2>Exp:7f</h2>
# <br>
# 1 layer 120 neurons

# %%
net = models.Sequential()
net.add(layers.Dense(480, input_shape = (480,6)))
net.add(layers.Dense (120, activation = 'relu'))
net.add(layers.Flatten())
net.add(layers.Dense(7, activation = 'sigmoid'))
net.summary()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_88 (Dense)             (None, 480, 480)          3360
# _________________________________________________________________
# dense_89 (Dense)             (None, 480, 120)          57720
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 57600)             0
# _________________________________________________________________
# dense_90 (Dense)             (None, 7)                 403207
# =================================================================
# Total params: 464,287
# Trainable params: 464,287
# Non-trainable params: 0
# _________________________________________________________________

# %%
net.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
hist = net.fit(train_data, train_labels, epochs = 14, validation_data = (val_data, val_labels))
# Out:
# Train on 52 samples, validate on 18 samples
# Epoch 1/14
# 52/52 [==============================] - 1s 14ms/step - loss: 2.0040 - accuracy: 0.1538 - val_loss: 1.8533 - val_accuracy: 0.3333
# Epoch 2/14
# 52/52 [==============================] - 0s 2ms/step - loss: 1.8195 - accuracy: 0.4423 - val_loss: 1.6983 - val_accuracy: 0.2222
# Epoch 3/14
# 52/52 [==============================] - 0s 2ms/step - loss: 1.6639 - accuracy: 0.2308 - val_loss: 1.5024 - val_accuracy: 0.2778
# Epoch 4/14
# 52/52 [==============================] - 0s 2ms/step - loss: 1.4248 - accuracy: 0.3846 - val_loss: 1.2470 - val_accuracy: 0.3889
# Epoch 5/14
# 52/52 [==============================] - 0s 2ms/step - loss: 1.1606 - accuracy: 0.5769 - val_loss: 1.0779 - val_accuracy: 0.5556
# Epoch 6/14
# 52/52 [==============================] - 0s 2ms/step - loss: 0.9841 - accuracy: 0.5385 - val_loss: 0.9901 - val_accuracy: 0.6111
# Epoch 7/14
# 52/52 [==============================] - 0s 2ms/step - loss: 0.8831 - accuracy: 0.6154 - val_loss: 0.9289 - val_accuracy: 0.5556
# Epoch 8/14
# 52/52 [==============================] - 0s 2ms/step - loss: 0.8307 - accuracy: 0.6154 - val_loss: 1.0741 - val_accuracy: 0.6111
# Epoch 9/14
# 52/52 [==============================] - 0s 2ms/step - loss: 0.8144 - accuracy: 0.6923 - val_loss: 0.8430 - val_accuracy: 0.5556
# Epoch 10/14
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6549 - accuracy: 0.8462 - val_loss: 0.7537 - val_accuracy: 0.7778
# Epoch 11/14
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5385 - accuracy: 0.8269 - val_loss: 0.7324 - val_accuracy: 0.6111
# Epoch 12/14
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4893 - accuracy: 0.8654 - val_loss: 0.7302 - val_accuracy: 0.7222
# Epoch 13/14
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4454 - accuracy: 0.8846 - val_loss: 0.6961 - val_accuracy: 0.7778
# Epoch 14/14
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8269 - val_loss: 0.6340 - val_accuracy: 0.7222

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy','Validation'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['loss','validation loss'], loc='upper right')
plt.show()

# %%
f = net.evaluate(test_data, test_labels)
f.insert(0,'120')
f.insert(1,test_no)
test_no = test_no + 1
summary.append(f)
# Out:
# 17/17 [==============================] - 0s 1ms/step

# %%
print(summary)
# Out:
# [['720', 1, 0.48032698035240173, 0.8235294222831726], ['600', 2, 0.5457100868225098, 0.8235294222831726], ['480', 3, 0.6175116896629333, 0.7647058963775635], ['360', 4, 0.9285157918930054, 0.529411792755127], ['240', 5, 0.6476141214370728, 0.8235294222831726], ['120', 6, 0.6900696754455566, 0.7058823704719543], ['720', 7, 1.1438034772872925, 0.7647058963775635], ['600', 8, 1.1077136993408203, 0.5882353186607361], ['480', 9, 1.3365801572799683, 0.4117647111415863], ['360', 10, 0.8697539567947388, 0.529411792755127], ['240', 11, 1.056951880455017, 0.529411792755127], ['120', 12, 0.9405328631401062, 0.7058823704719543], ['720', 13, 0.9574914574623108, 0.7058823704719543], ['600', 14, 0.9193838834762573, 0.5882353186607361], ['480', 15, 1.2223248481750488, 0.7058823704719543], ['360', 16, 1.439753532409668, 0.5882353186607361], ['240', 17, 0.9696654081344604, 0.529411792755127], ['120', 18, 0.8748618960380554, 0.7058823704719543], ['720', 19, 1.18405282497406, 0.5882353186607361], ['600', 20, 1.264286994934082, 0.5882353186607361], ['480', 21, 0.8842760920524597, 0.5882353186607361], ['360', 22, 0.8762089014053345, 0.7647058963775635], ['240', 23, 0.926914632320404, 0.6470588445663452], ['120', 24, 0.7044381499290466, 0.7058823704719543], ['720', 25, 1.0447733402252197, 0.47058823704719543], ['600', 26, 1.1201090812683105, 0.4117647111415863], ['480', 27, 0.8315189480781555, 0.5882353186607361], ['360', 28, 0.7533994317054749, 0.7058823704719543], ['240', 29, 0.688062310218811, 0.7647058963775635], ['120', 30, 0.6349231600761414, 0.7647058963775635]]

# %%
with open('ENB7_results.txt', 'wb') as fp:
    pickle.dump(summary, fp)
